# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')

theta = np.loadtxt('data/3751.txt',delimiter='\n',unpack=True)

# %%
plt.hist((theta-np.mean(theta))%(2*np.pi),bins=50);

# %%
i=0
up = []
for n in range(150001,299999):
    theta = np.loadtxt('data/'+str(n)+'.txt',delimiter='\n',unpack=True)
    up.append((theta-np.mean(theta))%(2*np.pi))

# %%
up2 = []
for n in range(100001,199999):
    theta2 = np.loadtxt('data2/'+str(n)+'.txt',delimiter='\n',unpack=True)
    up2.append((theta2-np.mean(theta2))%(2*np.pi))

# %%
plt.hist(tau,bins=5000);
plt.xlim([0,500])
#plt.yscale('log')
len(tau)
# Out:
# (0, 500)

# %%
up[1]
# Out:
# array([1.19878293, 1.49935293, 4.99538324, ..., 1.33400793, 4.83188824,
#        1.48982993])

# %%
time = 0
tau = []
cond = []
for j in range(500):
    cond = []
    time = 0
    for i in range(0,99998):
        if up[i][j]>4.5 or up[i][j]<2.0:
            cond.append(1)
        else:
            cond.append(0)
        
    for i in range(1,99998):
        if cond[i]==1 and cond[i-1]==0:
            tau.append(i-time)
            time = i

# %%
tau
# Out:
# [276,
#  34,
#  155,
#  3,
#  2,
#  225,
#  353,
#  12,
#  38,
#  3,
#  5,
#  9,
#  8,
#  4,
#  5,
#  4,
#  12,
#  44,
#  50,
#  25,
#  12,
#  9,
#  12,
#  3,
#  9,
#  2,
#  2,
#  39,
#  19,
#  3,
#  347,
#  49,
#  6,
#  9,
#  5,
#  16,
#  2,
#  31,
#  14,
#  2,
#  3,
#  6,
#  4,
#  4,
#  2,
#  10,
#  20,
#  12,
#  6,
#  55,
#  8,
#  2,
#  5,
#  547,
#  270,
#  6,
#  160,
#  155,
#  15,
#  5,
#  4,
#  5,
#  42,
#  3,
#  3,
#  120,
#  2,
#  4,
#  16,
#  5,
#  3,
#  7,
#  2,
#  2,
#  20,
#  4,
#  2,
#  5,
#  11,
#  3,
#  16,
#  5,
#  10,
#  8,
#  7,
#  12,
#  9,
#  10,
#  7,
#  4,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  12,
#  2,
#  3,
#  4,
#  12,
#  8,
#  40,
#  8,
#  9,
#  14,
#  7,
#  7,
#  2,
#  3,
#  4,
#  7,
#  4,
#  15,
#  5,
#  10,
#  3,
#  3,
#  3,
#  29,
#  5,
#  4,
#  7,
#  2,
#  21,
#  2,
#  2,
#  45,
#  9,
#  2,
#  5,
#  9,
#  3,
#  2,
#  4,
#  4,
#  27,
#  14,
#  2,
#  16,
#  5,
#  2,
#  14,
#  18,
#  2,
#  16,
#  50,
#  8,
#  66,
#  24,
#  4,
#  40,
#  31,
#  7,
#  4,
#  2,
#  39,
#  37,
#  5,
#  49,
#  17,
#  3,
#  12,
#  16,
#  2,
#  6,
#  4,
#  4,
#  2,
#  2,
#  4,
#  5,
#  12,
#  3,
#  8,
#  11,
#  2,
#  2,
#  4,
#  21,
#  50,
#  3,
#  4,
#  3,
#  3,
#  3,
#  5,
#  12,
#  10,
#  2,
#  3,
#  2,
#  19,
#  15,
#  5,
#  44,
#  9,
#  5,
#  4,
#  5,
#  3,
#  16,
#  3,
#  2,
#  2,
#  144,
#  25,
#  4,
#  21,
#  21,
#  38,
#  40,
#  2,
#  3,
#  6,
#  72,
#  2,
#  3,
#  18,
#  2,
#  2,
#  3,
#  87,
#  52,
#  8,
#  4,
#  3,
#  18,
#  9,
#  12,
#  60,
#  5,
#  16,
#  2,
#  6,
#  2,
#  3,
#  9,
#  21,
#  68,
#  7,
#  47,
#  6,
#  5,
#  4,
#  11,
#  3,
#  8,
#  3,
#  5,
#  8,
#  16,
#  5,
#  76,
#  3,
#  3,
#  3,
#  6,
#  12,
#  3,
#  3,
#  2,
#  25,
#  37,
#  5,
#  94,
#  4,
#  38,
#  12,
#  91,
#  4,
#  5,
#  2,
#  8,
#  2,
#  2,
#  9,
#  59,
#  24,
#  3,
#  2,
#  3,
#  3,
#  22,
#  5,
#  2,
#  10,
#  8,
#  7,
#  4,
#  5,
#  6,
#  5,
#  6,
#  14,
#  2,
#  30,
#  3,
#  9,
#  3,
#  4,
#  13,
#  2,
#  2,
#  9,
#  2,
#  5,
#  18,
#  7,
#  7,
#  7,
#  2,
#  2,
#  22,
#  69,
#  11,
#  5,
#  4,
#  5,
#  2,
#  16,
#  11,
#  2,
#  3,
#  6,
#  94,
#  13,
#  2,
#  9,
#  2,
#  2,
#  6,
#  7,
#  4,
#  51,
#  10,
#  3,
#  9,
#  2,
#  14,
#  10,
#  29,
#  24,
#  43,
#  17,
#  9,
#  5,
#  4,
#  127,
#  26,
#  2,
#  2,
#  3,
#  54,
#  67,
#  3,
#  4,
#  20,
#  4,
#  44,
#  61,
#  3,
#  29,
#  4,
#  4,
#  3,
#  5,
#  21,
#  12,
#  4,
#  2,
#  25,
#  3,
#  2,
#  9,
#  54,
#  4,
#  41,
#  3,
#  144,
#  13,
#  115,
#  15,
#  6,
#  47,
#  5,
#  31,
#  40,
#  11,
#  4,
#  3,
#  14,
#  3,
#  15,
#  14,
#  43,
#  9,
#  71,
#  9,
#  2,
#  20,
#  18,
#  81,
#  115,
#  19,
#  19,
#  14,
#  25,
#  61,
#  4,
#  2,
#  3,
#  4,
#  10,
#  60,
#  2,
#  2,
#  111,
#  220,
#  154,
#  81,
#  20,
#  4,
#  28,
#  2,
#  8,
#  22,
#  9,
#  5,
#  6,
#  103,
#  5,
#  14,
#  12,
#  9,
#  77,
#  23,
#  2,
#  145,
#  78,
#  16,
#  4,
#  2,
#  2,
#  2,
#  30,
#  3,
#  3,
#  5,
#  3,
#  2,
#  3,
#  6,
#  2,
#  46,
#  186,
#  189,
#  2,
#  86,
#  23,
#  2,
#  3,
#  58,
#  4,
#  9,
#  2,
#  39,
#  4,
#  84,
#  13,
#  45,
#  3,
#  3,
#  3,
#  2,
#  4,
#  4,
#  52,
#  2,
#  4,
#  24,
#  2,
#  5,
#  3,
#  10,
#  15,
#  3,
#  59,
#  5,
#  2,
#  3,
#  2,
#  8,
#  5,
#  150,
#  8,
#  41,
#  63,
#  2,
#  4,
#  11,
#  4,
#  42,
#  31,
#  14,
#  27,
#  146,
#  4,
#  2,
#  29,
#  2,
#  57,
#  25,
#  14,
#  3,
#  10,
#  2,
#  69,
#  4,
#  6,
#  36,
#  3,
#  97,
#  2,
#  92,
#  40,
#  3,
#  2,
#  136,
#  3,
#  11,
#  16,
#  38,
#  6,
#  32,
#  22,
#  106,
#  26,
#  20,
#  95,
#  53,
#  10,
#  10,
#  13,
#  40,
#  19,
#  3,
#  2,
#  2,
#  6,
#  2,
#  3,
#  5,
#  107,
#  73,
#  13,
#  6,
#  64,
#  2,
#  39,
#  195,
#  14,
#  37,
#  2,
#  4,
#  3,
#  9,
#  76,
#  167,
#  40,
#  4,
#  6,
#  162,
#  8,
#  5,
#  3,
#  5,
#  45,
#  5,
#  15,
#  77,
#  7,
#  104,
#  21,
#  5,
#  7,
#  4,
#  17,
#  39,
#  76,
#  4,
#  4,
#  13,
#  5,
#  3,
#  120,
#  10,
#  61,
#  2,
#  24,
#  8,
#  8,
#  7,
#  2,
#  4,
#  33,
#  45,
#  9,
#  4,
#  2,
#  31,
#  29,
#  5,
#  5,
#  7,
#  15,
#  7,
#  3,
#  16,
#  5,
#  59,
#  8,
#  12,
#  3,
#  66,
#  6,
#  87,
#  8,
#  5,
#  4,
#  5,
#  17,
#  10,
#  6,
#  71,
#  4,
#  2,
#  5,
#  16,
#  2,
#  49,
#  11,
#  6,
#  10,
#  3,
#  26,
#  2,
#  18,
#  4,
#  66,
#  88,
#  33,
#  2,
#  7,
#  3,
#  8,
#  4,
#  3,
#  11,
#  3,
#  2,
#  6,
#  28,
#  26,
#  2,
#  2,
#  4,
#  49,
#  166,
#  27,
#  13,
#  50,
#  21,
#  3,
#  21,
#  6,
#  21,
#  8,
#  44,
#  5,
#  2,
#  8,
#  22,
#  120,
#  5,
#  8,
#  2,
#  10,
#  17,
#  15,
#  6,
#  7,
#  22,
#  12,
#  9,
#  15,
#  3,
#  10,
#  16,
#  26,
#  36,
#  5,
#  33,
#  6,
#  5,
#  192,
#  2,
#  2,
#  6,
#  3,
#  4,
#  4,
#  4,
#  5,
#  7,
#  2,
#  24,
#  11,
#  169,
#  8,
#  2,
#  27,
#  8,
#  5,
#  5,
#  4,
#  147,
#  5,
#  3,
#  140,
#  45,
#  73,
#  31,
#  11,
#  17,
#  39,
#  16,
#  2,
#  42,
#  18,
#  11,
#  2,
#  4,
#  26,
#  18,
#  58,
#  93,
#  4,
#  2,
#  64,
#  3,
#  13,
#  4,
#  4,
#  2,
#  2,
#  11,
#  10,
#  5,
#  2,
#  8,
#  18,
#  21,
#  4,
#  40,
#  2,
#  59,
#  7,
#  155,
#  7,
#  122,
#  86,
#  119,
#  441,
#  35,
#  3,
#  23,
#  29,
#  7,
#  9,
#  2,
#  124,
#  161,
#  108,
#  20,
#  4,
#  576,
#  3,
#  2,
#  2,
#  2,
#  249,
#  468,
#  679,
#  39,
#  12,
#  7,
#  3,
#  7,
#  49,
#  65,
#  7,
#  22,
#  42,
#  49,
#  21,
#  78,
#  23,
#  5,
#  12,
#  15,
#  53,
#  12,
#  3,
#  2,
#  4,
#  3,
#  21,
#  3,
#  76,
#  6,
#  41,
#  32,
#  11,
#  5,
#  5,
#  3,
#  10,
#  5,
#  4,
#  3,
#  63,
#  2,
#  8,
#  76,
#  49,
#  22,
#  24,
#  2,
#  4,
#  3,
#  40,
#  2,
#  3,
#  24,
#  5,
#  6,
#  2,
#  2,
#  2,
#  3,
#  17,
#  10,
#  2,
#  33,
#  2,
#  6,
#  7,
#  3,
#  6,
#  3,
#  5,
#  4,
#  4,
#  3,
#  2,
#  2,
#  5,
#  24,
#  16,
#  17,
#  20,
#  3,
#  3,
#  11,
#  3,
#  6,
#  3,
#  2,
#  3,
#  13,
#  43,
#  18,
#  6,
#  25,
#  5,
#  14,
#  33,
#  3,
#  6,
#  14,
#  3,
#  12,
#  44,
#  10,
#  3,
#  2,
#  2,
#  4,
#  2,
#  21,
#  18,
#  2,
#  5,
#  21,
#  37,
#  17,
#  17,
#  3,
#  2,
#  12,
#  4,
#  4,
#  8,
#  8,
#  2,
#  4,
#  2,
#  13,
#  20,
#  4,
#  3,
#  11,
#  3,
#  10,
#  5,
#  6,
#  6,
#  18,
#  2,
#  3,
#  2,
#  5,
#  38,
#  17,
#  2,
#  20,
#  3,
#  2,
#  14,
#  3,
#  2,
#  8,
#  3,
#  5,
#  6,
#  34,
#  3,
#  19,
#  6,
#  8,
#  14,
#  19,
#  6,
#  11,
#  4,
#  7,
#  3,
#  2,
#  6,
#  39,
#  3,
#  5,
#  2,
#  4,
#  14,
#  29,
#  3,
#  2,
#  65,
#  7,
#  8,
#  5,
#  34,
#  15,
#  5,
#  6,
#  12,
#  2,
#  2,
#  6,
#  15,
#  13,
#  11,
#  7,
#  17,
#  3,
#  9,
#  22,
#  9,
#  9,
#  9,
#  2,
#  5,
#  19,
#  2,
#  7,
#  4,
#  2,
#  2,
#  ...]

# %%
freq2=np.repeat(0,99999)
t = 0

for i in range(len(tau)):
    t = tau[i]
    freq2[t] += 1

# %%
freq=np.repeat(0,149999)
t = 0

for i in range(len(tau)):
    t = tau[i]
    freq[t] += 1

# %%
freq2
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
new2 = freq2[2:500]/99999.0

# %%
new = freq[2:1000]/149999.0

# %%
plt.plot(new,label='N=1024')
plt.plot(new2,label='N=512')
plt.yscale("log")
plt.xlabel('$\\tau$')
plt.ylabel("$P(\\tau)$")
# Out:
# Text(0,0.5,u'$P(\\tau)$')
