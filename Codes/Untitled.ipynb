# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')
#Extract Data
x1,y1 = np.loadtxt('vicsek40.txt',delimiter='\t',unpack=True)
x2,y2 = np.loadtxt('vicsek40n.txt',delimiter='\t',unpack=True)
x3,y3 = np.loadtxt('vicsek40_1_05.txt',delimiter='\t',unpack=True)
x4,y4 = np.loadtxt('vicsek40_03_015.txt',delimiter='\t',unpack=True)
x5,y5 = np.loadtxt('vicsek40_04_02.txt',delimiter='\t',unpack=True)
x6,y6 = np.loadtxt('vicsek40_06_03.txt',delimiter='\t',unpack=True)

plt.plot(x1,y1,label='1')
plt.plot(x2,y2,label='2')
plt.plot(x3,y3,label='3')
plt.plot(x4,y4,label='4')
plt.plot(x5,y5,label='5')
plt.plot(x6,y6,label='6')
plt.legend()

# %%
x1,y1 = np.loadtxt('vicsek40_01_01.txt',delimiter='\t',unpack=True)
x2,y2 = np.loadtxt('vicsek40_01_03.txt',delimiter='\t',unpack=True)
x3,y3 = np.loadtxt('vicsek40_01_05.txt',delimiter='\t',unpack=True)
x4,y4 = np.loadtxt('vicsek40_01_07.txt',delimiter='\t',unpack=True)
x5,y5 = np.loadtxt('vicsek40_01_09.txt',delimiter='\t',unpack=True)
plt.plot(x1,y1,label='1')
plt.plot(x2,y2,label='2')
plt.plot(x3,y3,label='3')
plt.plot(x4,y4,label='4')
plt.plot(x5,y5,label='5')
plt.legend()

# %%
x1,y1 = np.loadtxt('vicsek40_03_01.txt',delimiter='\t',unpack=True)
x2,y2 = np.loadtxt('vicsek40_03_03.txt',delimiter='\t',unpack=True)
x3,y3 = np.loadtxt('vicsek40_03_05.txt',delimiter='\t',unpack=True)
x4,y4 = np.loadtxt('vicsek40_03_07.txt',delimiter='\t',unpack=True)
x5,y5 = np.loadtxt('vicsek40_03_09.txt',delimiter='\t',unpack=True)
plt.plot(x1,y1,label='1')
plt.plot(x2,y2,label='2')
plt.plot(x3,y3,label='3')
plt.plot(x4,y4,label='4')
plt.plot(x5,y5,label='5')
plt.legend()

# %%
x1,y1 = np.loadtxt('vicsek40_05_01.txt',delimiter='\t',unpack=True)
x2,y2 = np.loadtxt('vicsek40_05_03.txt',delimiter='\t',unpack=True)
x3,y3 = np.loadtxt('vicsek40_05_05.txt',delimiter='\t',unpack=True)
x4,y4 = np.loadtxt('vicsek40_05_07.txt',delimiter='\t',unpack=True)
x5,y5 = np.loadtxt('vicsek40_05_09.txt',delimiter='\t',unpack=True)
plt.plot(x1,y1,label='1')
plt.plot(x2,y2,label='2')
plt.plot(x3,y3,label='3')
plt.plot(x4,y4,label='4')
plt.plot(x5,y5,label='5')
plt.legend()

# %%
x1,y1 = np.loadtxt('vicsek40_07_01.txt',delimiter='\t',unpack=True)
x2,y2 = np.loadtxt('vicsek40_07_03.txt',delimiter='\t',unpack=True)
x3,y3 = np.loadtxt('vicsek40_07_05.txt',delimiter='\t',unpack=True)
x4,y4 = np.loadtxt('vicsek40_07_07.txt',delimiter='\t',unpack=True)
plt.plot(x1,y1,label='1')
plt.plot(x2,y2,label='2')
plt.plot(x3,y3,label='3')
plt.plot(x4,y4,label='4')
plt.plot(x5,y5,label='5')
plt.legend()
